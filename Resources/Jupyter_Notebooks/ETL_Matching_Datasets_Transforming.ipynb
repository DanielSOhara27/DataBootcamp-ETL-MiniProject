# %% [markdown]
# # Matching Datasets PGJ Delitos y Zonas Patrullaje
# We are using two separate datasets and have been performing ETL operations on them in order to be able to link a crime incident to Police Patrol Zones. We are doing this by measuring the distance from the reported crime to the center of the patrol zone. By doing this, we hope to get insights in the effectiveness of police patrolling, to see if we need more police cars, or whatever other crime statistics we can find.
#
# (We have taken a list of distance from the center of the patrol zone to each point in the perimeter of the zone - Look at Jupyter Notebook ETL_ZonasPatrullaje_Transforming)

# %%
# We are importing the necessary libraries to start working
import pandas as pd
import numpy as np
from os import path
from ast import literal_eval
from vincenty import vincenty

# %%
# Setting filename and location
file_zonas = path.join("..","Clean","after_transform","transformed_ZonasPatrullaje.csv")
file_delitos_lite = path.join("..","Clean","after_transform","transformed_lite_CarpetasInvestigacion.csv")

# Read Purchasing File and store into Pandas data frame
patrullaje_df = pd.read_csv(file_zonas, sep=';')
delitos_df = pd.read_csv(file_delitos_lite, sep=';')

# %%
# Making sure that this is correct clean dataset
patrullaje_df.head()
# Out:
#                         Geopoint  \
# 0  19.4559485754, -99.1339187632
# 1  19.4489311584, -99.1492549723
# 2  19.4466167038, -99.1372059309
# 3  19.4345863188, -99.1559474685
# 4  19.4287224255, -99.1566989128
#
#                                             Geoshape    Alcaldía   Sector 18  \
# 0  {"type": "Polygon", "coordinates": [[[-99.1373...  CUAUHTEMOC  TLATELOLCO
# 1  {"type": "Polygon", "coordinates": [[[-99.1529...  CUAUHTEMOC  BUENAVISTA
# 2  {"type": "Polygon", "coordinates": [[[-99.1388...  CUAUHTEMOC  BUENAVISTA
# 3  {"type": "Polygon", "coordinates": [[[-99.1587...  CUAUHTEMOC  REVOLUCION
# 4  {"type": "Polygon", "coordinates": [[[-99.1544...  CUAUHTEMOC  REVOLUCION
#
#    Área km2          x          y      mean  standard_Deviation  \
# 0  0.599031 -99.133437  19.455969  0.527474            0.014291
# 1  0.542691 -99.149153  19.448988  0.453007            0.006291
# 2  0.139906 -99.136628  19.446343  0.309541            0.007696
# 3  0.263673 -99.156147  19.434677  0.362777            0.025262
# 4  0.294612 -99.156832  19.428315  0.378270            0.007552
#
#                                            distances
# 0  [0.534167, 0.437955, 0.262072, 0.536854, 0.648...
# 1  [0.526167, 0.320717, 0.468643, 0.542789, 0.444...
# 2  [0.403358, 0.375808, 0.340076, 0.304342, 0.299...
# 3  [0.443341, 0.16611, 0.507736, 0.496656, 0.2699...
# 4  [0.469645, 0.426766, 0.407346, 0.198526, 0.457...

# %%
# Making sure that this is correct clean dataset
delitos_df.head()
# Out:
#    0     19.35177196, -99.220583382
# 0  1  19.5085668561, -99.2083000919
# 1  2  19.4663394581, -99.1243321831
# 2  3  19.4628200485, -99.1163214933
# 3  4  19.4503050199, -99.2199589505
# 4  5  19.3819955868, -99.2307361552

# %%
print(delitos_df.columns)
print(delitos_df.count())
# Out:
# Index(['0', '19.35177196, -99.220583382'], dtype='object')
# 0                             245159
# 19.35177196, -99.220583382    245159
# dtype: int64

# %%
# Prepare the delitos_df dataframe
delitos_y = list()
delitos_x = list()
for delito in delitos_df['19.35177196, -99.220583382']:
    data = delito.split(',')
    delitos_y.append(data[0])
    delitos_x.append(data[1])

delitos_df = pd.DataFrame({'y':delitos_y, 'x':delitos_x})
delitos_df.head()
# Out:
#                y                x
# 0  19.5085668561   -99.2083000919
# 1  19.4663394581   -99.1243321831
# 2  19.4628200485   -99.1163214933
# 3  19.4503050199   -99.2199589505
# 4  19.3819955868   -99.2307361552

# %% [markdown]
# # Measuring the mean distance (with a 2 standard Deviation Margin of error)
# To see if a crime was committed near a Patrol Zone we are calculating the distance between each row's x & y in delitos_df against each geopoint in patrullaje_df. To do this, we are using Vicenty's Formula for distance in an elipsis to measure the distance in KM.

# %%
counter = 0

#This list will contain all the crimes committed near each patrol zone
all_crimes_near = list()

# We are comparing each patrol zone (about 698) against each crime reported in 2018 (about 250K)
# Not very efficient, will optimize better in the future
for index, row in patrullaje_df.iterrows():
    
    # This is the Patrol Zone's info
    geopoint = row['Geopoint'].split(",")   
    x_origin = float(geopoint[1])
    y_origin = float(geopoint[0])
    mean = row['mean']
    standard_deviation = row['standard_Deviation']
    
    # This list will contain all the crimes committed near this partcular row's geopoint
    crimes_near = list()
    
    # Measuring the distance
    for index_2 in range(len(delitos_y)):
        distance = vincenty([x_origin, y_origin],[float(delitos_x[index_2]), float(delitos_y[index_2])])
        
        #if(index_2 < 20):
            #print(f"{counter}) distance: {distance}, mean: {mean}, sd: {standard_deviation}")
        
        # I only care for crimes committed near the patrol zone
        if(distance <= ( mean + (2*standard_deviation) ) ):
            crimes_near.append(index_2)
    
    #We are now finished with this particular row's geopoint
    all_crimes_near.append(crimes_near)
    print(f"Finished with Patrol Zone #{counter} -> crimes: {len(crimes_near)}")
    counter +=1

    
print("Finished")
# Out:
# Finished with Patrol Zone #0 -> crimes: 5814
# Finished with Patrol Zone #1 -> crimes: 5769
# Finished with Patrol Zone #2 -> crimes: 2333
# Finished with Patrol Zone #3 -> crimes: 4370
# Finished with Patrol Zone #4 -> crimes: 3420
# Finished with Patrol Zone #5 -> crimes: 4859
# Finished with Patrol Zone #6 -> crimes: 5421
# Finished with Patrol Zone #7 -> crimes: 1761
# Finished with Patrol Zone #8 -> crimes: 1933
# Finished with Patrol Zone #9 -> crimes: 2355
# Finished with Patrol Zone #10 -> crimes: 2733
# Finished with Patrol Zone #11 -> crimes: 2697
# Finished with Patrol Zone #12 -> crimes: 1141
# Finished with Patrol Zone #13 -> crimes: 2136
# Finished with Patrol Zone #14 -> crimes: 1310
# Finished with Patrol Zone #15 -> crimes: 963
# Finished with Patrol Zone #16 -> crimes: 1202
# Finished with Patrol Zone #17 -> crimes: 2199
# Finished with Patrol Zone #18 -> crimes: 1530
# Finished with Patrol Zone #19 -> crimes: 1663
# Finished with Patrol Zone #20 -> crimes: 1357
# Finished with Patrol Zone #21 -> crimes: 1650
# Finished with Patrol Zone #22 -> crimes: 3265
# Finished with Patrol Zone #23 -> crimes: 861
# Finished with Patrol Zone #24 -> crimes: 1641
# Finished with Patrol Zone #25 -> crimes: 1157
# Finished with Patrol Zone #26 -> crimes: 907
# Finished with Patrol Zone #27 -> crimes: 803
# Finished with Patrol Zone #28 -> crimes: 1280
# Finished with Patrol Zone #29 -> crimes: 1789
# Finished with Patrol Zone #30 -> crimes: 1266
# Finished with Patrol Zone #31 -> crimes: 1877
# Finished with Patrol Zone #32 -> crimes: 891
# Finished with Patrol Zone #33 -> crimes: 1085
# Finished with Patrol Zone #34 -> crimes: 4062
# Finished with Patrol Zone #35 -> crimes: 3171
# Finished with Patrol Zone #36 -> crimes: 4156
# Finished with Patrol Zone #37 -> crimes: 635
# Finished with Patrol Zone #38 -> crimes: 1236
# Finished with Patrol Zone #39 -> crimes: 2035
# Finished with Patrol Zone #40 -> crimes: 659
# Finished with Patrol Zone #41 -> crimes: 2586
# Finished with Patrol Zone #42 -> crimes: 2687
# Finished with Patrol Zone #43 -> crimes: 2664
# Finished with Patrol Zone #44 -> crimes: 2616
# Finished with Patrol Zone #45 -> crimes: 5048
# Finished with Patrol Zone #46 -> crimes: 1480
# Finished with Patrol Zone #47 -> crimes: 3709
# Finished with Patrol Zone #48 -> crimes: 3677
# Finished with Patrol Zone #49 -> crimes: 1734
# Finished with Patrol Zone #50 -> crimes: 5441
# Finished with Patrol Zone #51 -> crimes: 5523
# Finished with Patrol Zone #52 -> crimes: 2494
# Finished with Patrol Zone #53 -> crimes: 4159
# Finished with Patrol Zone #54 -> crimes: 2113
# Finished with Patrol Zone #55 -> crimes: 3287
# Finished with Patrol Zone #56 -> crimes: 2356
# Finished with Patrol Zone #57 -> crimes: 3629
# Finished with Patrol Zone #58 -> crimes: 3321
# Finished with Patrol Zone #59 -> crimes: 1934
# Finished with Patrol Zone #60 -> crimes: 1499
# Finished with Patrol Zone #61 -> crimes: 3101
# Finished with Patrol Zone #62 -> crimes: 2137
# Finished with Patrol Zone #63 -> crimes: 3000
# Finished with Patrol Zone #64 -> crimes: 869
# Finished with Patrol Zone #65 -> crimes: 2839
# Finished with Patrol Zone #66 -> crimes: 1166
# Finished with Patrol Zone #67 -> crimes: 3000
# Finished with Patrol Zone #68 -> crimes: 2441
# Finished with Patrol Zone #69 -> crimes: 2604
# Finished with Patrol Zone #70 -> crimes: 4071
# Finished with Patrol Zone #71 -> crimes: 4607
# Finished with Patrol Zone #72 -> crimes: 3937
# Finished with Patrol Zone #73 -> crimes: 2061
# Finished with Patrol Zone #74 -> crimes: 1068
# Finished with Patrol Zone #75 -> crimes: 530
# Finished with Patrol Zone #76 -> crimes: 894
# Finished with Patrol Zone #77 -> crimes: 8172
# Finished with Patrol Zone #78 -> crimes: 6048
# Finished with Patrol Zone #79 -> crimes: 1016
# Finished with Patrol Zone #80 -> crimes: 4027
# Finished with Patrol Zone #81 -> crimes: 1678
# Finished with Patrol Zone #82 -> crimes: 1019
# Finished with Patrol Zone #83 -> crimes: 3720
# Finished with Patrol Zone #84 -> crimes: 2000
# Finished with Patrol Zone #85 -> crimes: 1914
# Finished with Patrol Zone #86 -> crimes: 1355
# Finished with Patrol Zone #87 -> crimes: 543
# Finished with Patrol Zone #88 -> crimes: 4600
# Finished with Patrol Zone #89 -> crimes: 3405
# Finished with Patrol Zone #90 -> crimes: 259
# Finished with Patrol Zone #91 -> crimes: 2697
# Finished with Patrol Zone #92 -> crimes: 1282
# Finished with Patrol Zone #93 -> crimes: 1586
# Finished with Patrol Zone #94 -> crimes: 4386
# Finished with Patrol Zone #95 -> crimes: 3094
# Finished with Patrol Zone #96 -> crimes: 1440
# Finished with Patrol Zone #97 -> crimes: 2803
# Finished with Patrol Zone #98 -> crimes: 2342
# Finished with Patrol Zone #99 -> crimes: 1825
# Finished with Patrol Zone #100 -> crimes: 5075
# Finished with Patrol Zone #101 -> crimes: 6328
# Finished with Patrol Zone #102 -> crimes: 3645
# Finished with Patrol Zone #103 -> crimes: 2110
# Finished with Patrol Zone #104 -> crimes: 3095
# Finished with Patrol Zone #105 -> crimes: 1492
# Finished with Patrol Zone #106 -> crimes: 2022
# Finished with Patrol Zone #107 -> crimes: 8247
# Finished with Patrol Zone #108 -> crimes: 2448
# Finished with Patrol Zone #109 -> crimes: 2448
# Finished with Patrol Zone #110 -> crimes: 716
# Finished with Patrol Zone #111 -> crimes: 3172
# Finished with Patrol Zone #112 -> crimes: 2579
# Finished with Patrol Zone #113 -> crimes: 2761
# Finished with Patrol Zone #114 -> crimes: 2022
# Finished with Patrol Zone #115 -> crimes: 3041
# Finished with Patrol Zone #116 -> crimes: 1958
# Finished with Patrol Zone #117 -> crimes: 3453
# Finished with Patrol Zone #118 -> crimes: 2412
# Finished with Patrol Zone #119 -> crimes: 6282
# Finished with Patrol Zone #120 -> crimes: 1990
# Finished with Patrol Zone #121 -> crimes: 1795
# Finished with Patrol Zone #122 -> crimes: 2447
# Finished with Patrol Zone #123 -> crimes: 1066
# Finished with Patrol Zone #124 -> crimes: 1543
# Finished with Patrol Zone #125 -> crimes: 1395
# Finished with Patrol Zone #126 -> crimes: 1376
# Finished with Patrol Zone #127 -> crimes: 3624
# Finished with Patrol Zone #128 -> crimes: 4424
# Finished with Patrol Zone #129 -> crimes: 1519
# Finished with Patrol Zone #130 -> crimes: 1458
# Finished with Patrol Zone #131 -> crimes: 1077
# Finished with Patrol Zone #132 -> crimes: 1715
# Finished with Patrol Zone #133 -> crimes: 1045
# Finished with Patrol Zone #134 -> crimes: 1857
# Finished with Patrol Zone #135 -> crimes: 1656
# Finished with Patrol Zone #136 -> crimes: 2012
# Finished with Patrol Zone #137 -> crimes: 1482
# Finished with Patrol Zone #138 -> crimes: 2060
# Finished with Patrol Zone #139 -> crimes: 2876
# Finished with Patrol Zone #140 -> crimes: 1235
# Finished with Patrol Zone #141 -> crimes: 4225
# Finished with Patrol Zone #142 -> crimes: 1282
# Finished with Patrol Zone #143 -> crimes: 1614
# Finished with Patrol Zone #144 -> crimes: 1294
# Finished with Patrol Zone #145 -> crimes: 1722
# Finished with Patrol Zone #146 -> crimes: 3302
# Finished with Patrol Zone #147 -> crimes: 1154
# Finished with Patrol Zone #148 -> crimes: 2922
# Finished with Patrol Zone #149 -> crimes: 6102
# Finished with Patrol Zone #150 -> crimes: 2686
# Finished with Patrol Zone #151 -> crimes: 1443
# Finished with Patrol Zone #152 -> crimes: 4195
# Finished with Patrol Zone #153 -> crimes: 8660
# Finished with Patrol Zone #154 -> crimes: 1008
# Finished with Patrol Zone #155 -> crimes: 2245
# Finished with Patrol Zone #156 -> crimes: 1414
# Finished with Patrol Zone #157 -> crimes: 2285
# Finished with Patrol Zone #158 -> crimes: 3708
# Finished with Patrol Zone #159 -> crimes: 1294
# Finished with Patrol Zone #160 -> crimes: 1410
# Finished with Patrol Zone #161 -> crimes: 4717
# Finished with Patrol Zone #162 -> crimes: 2221
# Finished with Patrol Zone #163 -> crimes: 2882
# Finished with Patrol Zone #164 -> crimes: 4578
# Finished with Patrol Zone #165 -> crimes: 1260
# Finished with Patrol Zone #166 -> crimes: 1448
# Finished with Patrol Zone #167 -> crimes: 6981
# Finished with Patrol Zone #168 -> crimes: 1454
# Finished with Patrol Zone #169 -> crimes: 2565
# Finished with Patrol Zone #170 -> crimes: 841
# Finished with Patrol Zone #171 -> crimes: 2367
# Finished with Patrol Zone #172 -> crimes: 3579
# Finished with Patrol Zone #173 -> crimes: 3722
# Finished with Patrol Zone #174 -> crimes: 1091
# Finished with Patrol Zone #175 -> crimes: 7260
# Finished with Patrol Zone #176 -> crimes: 10456
# Finished with Patrol Zone #177 -> crimes: 35723
# Finished with Patrol Zone #178 -> crimes: 21691
# Finished with Patrol Zone #179 -> crimes: 7521
# Finished with Patrol Zone #180 -> crimes: 2858
# Finished with Patrol Zone #181 -> crimes: 5528
# Finished with Patrol Zone #182 -> crimes: 1947
# Finished with Patrol Zone #183 -> crimes: 4659
# Finished with Patrol Zone #184 -> crimes: 4970
# Finished with Patrol Zone #185 -> crimes: 6749
# Finished with Patrol Zone #186 -> crimes: 2598
# Finished with Patrol Zone #187 -> crimes: 4415
# Finished with Patrol Zone #188 -> crimes: 1506
# Finished with Patrol Zone #189 -> crimes: 1192
# Finished with Patrol Zone #190 -> crimes: 2680
# Finished with Patrol Zone #191 -> crimes: 1186
# Finished with Patrol Zone #192 -> crimes: 3494
# Finished with Patrol Zone #193 -> crimes: 5954
# Finished with Patrol Zone #194 -> crimes: 3240
# Finished with Patrol Zone #195 -> crimes: 5575
# Finished with Patrol Zone #196 -> crimes: 520
# Finished with Patrol Zone #197 -> crimes: 10326
# Finished with Patrol Zone #198 -> crimes: 5234
# Finished with Patrol Zone #199 -> crimes: 2861
# Finished with Patrol Zone #200 -> crimes: 3635
# Finished with Patrol Zone #201 -> crimes: 1934
# Finished with Patrol Zone #202 -> crimes: 1495
# Finished with Patrol Zone #203 -> crimes: 4563
# Finished with Patrol Zone #204 -> crimes: 3231
# Finished with Patrol Zone #205 -> crimes: 1905
# Finished with Patrol Zone #206 -> crimes: 2013
# Finished with Patrol Zone #207 -> crimes: 1607
# Finished with Patrol Zone #208 -> crimes: 4302
# Finished with Patrol Zone #209 -> crimes: 4307
# Finished with Patrol Zone #210 -> crimes: 2618
# Finished with Patrol Zone #211 -> crimes: 979
# Finished with Patrol Zone #212 -> crimes: 5299
# Finished with Patrol Zone #213 -> crimes: 668
# Finished with Patrol Zone #214 -> crimes: 2149
# Finished with Patrol Zone #215 -> crimes: 2190
# Finished with Patrol Zone #216 -> crimes: 1328
# Finished with Patrol Zone #217 -> crimes: 2060
# Finished with Patrol Zone #218 -> crimes: 2184
# Finished with Patrol Zone #219 -> crimes: 2958
# Finished with Patrol Zone #220 -> crimes: 3372
# Finished with Patrol Zone #221 -> crimes: 5830
# Finished with Patrol Zone #222 -> crimes: 1565
# Finished with Patrol Zone #223 -> crimes: 3732
# Finished with Patrol Zone #224 -> crimes: 3114
# Finished with Patrol Zone #225 -> crimes: 1322
# Finished with Patrol Zone #226 -> crimes: 1538
# Finished with Patrol Zone #227 -> crimes: 935
# Finished with Patrol Zone #228 -> crimes: 1046
# Finished with Patrol Zone #229 -> crimes: 1361
# Finished with Patrol Zone #230 -> crimes: 3509
# Finished with Patrol Zone #231 -> crimes: 1906
# Finished with Patrol Zone #232 -> crimes: 2408
# Finished with Patrol Zone #233 -> crimes: 1283
# Finished with Patrol Zone #234 -> crimes: 1733
# Finished with Patrol Zone #235 -> crimes: 1768
# Finished with Patrol Zone #236 -> crimes: 1744
# Finished with Patrol Zone #237 -> crimes: 12528
# Finished with Patrol Zone #238 -> crimes: 967
# Finished with Patrol Zone #239 -> crimes: 2607
# Finished with Patrol Zone #240 -> crimes: 1486
# Finished with Patrol Zone #241 -> crimes: 4065
# Finished with Patrol Zone #242 -> crimes: 3762
# Finished with Patrol Zone #243 -> crimes: 3439
# Finished with Patrol Zone #244 -> crimes: 1804
# Finished with Patrol Zone #245 -> crimes: 5650
# Finished with Patrol Zone #246 -> crimes: 3413
# Finished with Patrol Zone #247 -> crimes: 1323
# Finished with Patrol Zone #248 -> crimes: 4991
# Finished with Patrol Zone #249 -> crimes: 2285
# Finished with Patrol Zone #250 -> crimes: 12852
# Finished with Patrol Zone #251 -> crimes: 3995
# Finished with Patrol Zone #252 -> crimes: 3140
# Finished with Patrol Zone #253 -> crimes: 3096
# Finished with Patrol Zone #254 -> crimes: 1097
# Finished with Patrol Zone #255 -> crimes: 2748
# Finished with Patrol Zone #256 -> crimes: 2194
# Finished with Patrol Zone #257 -> crimes: 2508
# Finished with Patrol Zone #258 -> crimes: 519
# Finished with Patrol Zone #259 -> crimes: 2090
# Finished with Patrol Zone #260 -> crimes: 1150
# Finished with Patrol Zone #261 -> crimes: 1362
# Finished with Patrol Zone #262 -> crimes: 4887
# Finished with Patrol Zone #263 -> crimes: 2437
# Finished with Patrol Zone #264 -> crimes: 1449
# Finished with Patrol Zone #265 -> crimes: 2035
# Finished with Patrol Zone #266 -> crimes: 3623
# Finished with Patrol Zone #267 -> crimes: 3067
# Finished with Patrol Zone #268 -> crimes: 3777
# Finished with Patrol Zone #269 -> crimes: 1721
# Finished with Patrol Zone #270 -> crimes: 3236
# Finished with Patrol Zone #271 -> crimes: 12016
# Finished with Patrol Zone #272 -> crimes: 2615
# Finished with Patrol Zone #273 -> crimes: 1837
# Finished with Patrol Zone #274 -> crimes: 1218
# Finished with Patrol Zone #275 -> crimes: 3059
# Finished with Patrol Zone #276 -> crimes: 5985
# Finished with Patrol Zone #277 -> crimes: 865
# Finished with Patrol Zone #278 -> crimes: 1220
# Finished with Patrol Zone #279 -> crimes: 2244
# Finished with Patrol Zone #280 -> crimes: 3547
# Finished with Patrol Zone #281 -> crimes: 2103
# Finished with Patrol Zone #282 -> crimes: 2515
# Finished with Patrol Zone #283 -> crimes: 5718
# Finished with Patrol Zone #284 -> crimes: 1883
# Finished with Patrol Zone #285 -> crimes: 4265
# Finished with Patrol Zone #286 -> crimes: 1842
# Finished with Patrol Zone #287 -> crimes: 975
# Finished with Patrol Zone #288 -> crimes: 2171
# Finished with Patrol Zone #289 -> crimes: 1090
# Finished with Patrol Zone #290 -> crimes: 1638
# Finished with Patrol Zone #291 -> crimes: 2214
# Finished with Patrol Zone #292 -> crimes: 1465
# Finished with Patrol Zone #293 -> crimes: 4259
# Finished with Patrol Zone #294 -> crimes: 2920
# Finished with Patrol Zone #295 -> crimes: 5911
# Finished with Patrol Zone #296 -> crimes: 1032
# Finished with Patrol Zone #297 -> crimes: 8159
# Finished with Patrol Zone #298 -> crimes: 20331
# Finished with Patrol Zone #299 -> crimes: 3330
# Finished with Patrol Zone #300 -> crimes: 4489
# Finished with Patrol Zone #301 -> crimes: 3695
# Finished with Patrol Zone #302 -> crimes: 862
# Finished with Patrol Zone #303 -> crimes: 7014
# Finished with Patrol Zone #304 -> crimes: 5494
# Finished with Patrol Zone #305 -> crimes: 7655
# Finished with Patrol Zone #306 -> crimes: 4911
# Finished with Patrol Zone #307 -> crimes: 6181
# Finished with Patrol Zone #308 -> crimes: 4187
# Finished with Patrol Zone #309 -> crimes: 2540
# Finished with Patrol Zone #310 -> crimes: 3233
# Finished with Patrol Zone #311 -> crimes: 831
# Finished with Patrol Zone #312 -> crimes: 665
# Finished with Patrol Zone #313 -> crimes: 2293
# Finished with Patrol Zone #314 -> crimes: 5045
# Finished with Patrol Zone #315 -> crimes: 4858
# Finished with Patrol Zone #316 -> crimes: 3600
# Finished with Patrol Zone #317 -> crimes: 9423
# Finished with Patrol Zone #318 -> crimes: 4682
# Finished with Patrol Zone #319 -> crimes: 23650
# Finished with Patrol Zone #320 -> crimes: 4002
# Finished with Patrol Zone #321 -> crimes: 3320
# Finished with Patrol Zone #322 -> crimes: 14682
# Finished with Patrol Zone #323 -> crimes: 9533
# Finished with Patrol Zone #324 -> crimes: 5811
# Finished with Patrol Zone #325 -> crimes: 3403
# Finished with Patrol Zone #326 -> crimes: 8972
# Finished with Patrol Zone #327 -> crimes: 1318
# Finished with Patrol Zone #328 -> crimes: 261
# Finished with Patrol Zone #329 -> crimes: 963
# Finished with Patrol Zone #330 -> crimes: 426
# Finished with Patrol Zone #331 -> crimes: 666
# Finished with Patrol Zone #332 -> crimes: 2337
# Finished with Patrol Zone #333 -> crimes: 1474
# Finished with Patrol Zone #334 -> crimes: 4978
# Finished with Patrol Zone #335 -> crimes: 4174
# Finished with Patrol Zone #336 -> crimes: 2864
# Finished with Patrol Zone #337 -> crimes: 2543
# Finished with Patrol Zone #338 -> crimes: 2433
# Finished with Patrol Zone #339 -> crimes: 1104
# Finished with Patrol Zone #340 -> crimes: 2638
# Finished with Patrol Zone #341 -> crimes: 2539
# Finished with Patrol Zone #342 -> crimes: 2462
# Finished with Patrol Zone #343 -> crimes: 1774
# Finished with Patrol Zone #344 -> crimes: 1160
# Finished with Patrol Zone #345 -> crimes: 1827
# Finished with Patrol Zone #346 -> crimes: 1763
# Finished with Patrol Zone #347 -> crimes: 1702
# Finished with Patrol Zone #348 -> crimes: 1177
# Finished with Patrol Zone #349 -> crimes: 2599
# Finished with Patrol Zone #350 -> crimes: 4525
# Finished with Patrol Zone #351 -> crimes: 1789
# Finished with Patrol Zone #352 -> crimes: 3669
# Finished with Patrol Zone #353 -> crimes: 2225
# Finished with Patrol Zone #354 -> crimes: 2148
# Finished with Patrol Zone #355 -> crimes: 885
# Finished with Patrol Zone #356 -> crimes: 1258
# Finished with Patrol Zone #357 -> crimes: 8481
# Finished with Patrol Zone #358 -> crimes: 925
# Finished with Patrol Zone #359 -> crimes: 388
# Finished with Patrol Zone #360 -> crimes: 2474
# Finished with Patrol Zone #361 -> crimes: 1601
# Finished with Patrol Zone #362 -> crimes: 1707
# Finished with Patrol Zone #363 -> crimes: 2208
# Finished with Patrol Zone #364 -> crimes: 2357
# Finished with Patrol Zone #365 -> crimes: 3228
# Finished with Patrol Zone #366 -> crimes: 1763
# Finished with Patrol Zone #367 -> crimes: 7827
# Finished with Patrol Zone #368 -> crimes: 2533
# Finished with Patrol Zone #369 -> crimes: 1561
# Finished with Patrol Zone #370 -> crimes: 1695
# Finished with Patrol Zone #371 -> crimes: 1532
# Finished with Patrol Zone #372 -> crimes: 1854
# Finished with Patrol Zone #373 -> crimes: 2585
# Finished with Patrol Zone #374 -> crimes: 2942
# Finished with Patrol Zone #375 -> crimes: 1867
# Finished with Patrol Zone #376 -> crimes: 1774
# Finished with Patrol Zone #377 -> crimes: 1470
# Finished with Patrol Zone #378 -> crimes: 993
# Finished with Patrol Zone #379 -> crimes: 1507
# Finished with Patrol Zone #380 -> crimes: 2253
# Finished with Patrol Zone #381 -> crimes: 1839
# Finished with Patrol Zone #382 -> crimes: 17059
# Finished with Patrol Zone #383 -> crimes: 3217
# Finished with Patrol Zone #384 -> crimes: 4818
# Finished with Patrol Zone #385 -> crimes: 1306
# Finished with Patrol Zone #386 -> crimes: 4994
# Finished with Patrol Zone #387 -> crimes: 1068
# Finished with Patrol Zone #388 -> crimes: 676
# Finished with Patrol Zone #389 -> crimes: 2028
# Finished with Patrol Zone #390 -> crimes: 938
# Finished with Patrol Zone #391 -> crimes: 2772
# Finished with Patrol Zone #392 -> crimes: 597
# Finished with Patrol Zone #393 -> crimes: 1102
# Finished with Patrol Zone #394 -> crimes: 6602
# Finished with Patrol Zone #395 -> crimes: 17844
# Finished with Patrol Zone #396 -> crimes: 7282
# Finished with Patrol Zone #397 -> crimes: 3388
# Finished with Patrol Zone #398 -> crimes: 5776
# Finished with Patrol Zone #399 -> crimes: 5023
# Finished with Patrol Zone #400 -> crimes: 1552
# Finished with Patrol Zone #401 -> crimes: 3042
# Finished with Patrol Zone #402 -> crimes: 2059
# Finished with Patrol Zone #403 -> crimes: 1479
# Finished with Patrol Zone #404 -> crimes: 2981
# Finished with Patrol Zone #405 -> crimes: 2610
# Finished with Patrol Zone #406 -> crimes: 3153
# Finished with Patrol Zone #407 -> crimes: 1261
# Finished with Patrol Zone #408 -> crimes: 3142
# Finished with Patrol Zone #409 -> crimes: 4559
# Finished with Patrol Zone #410 -> crimes: 2425
# Finished with Patrol Zone #411 -> crimes: 4147
# Finished with Patrol Zone #412 -> crimes: 2758
# Finished with Patrol Zone #413 -> crimes: 1545
# Finished with Patrol Zone #414 -> crimes: 1190
# Finished with Patrol Zone #415 -> crimes: 3304
# Finished with Patrol Zone #416 -> crimes: 1606
# Finished with Patrol Zone #417 -> crimes: 1249
# Finished with Patrol Zone #418 -> crimes: 1462
# Finished with Patrol Zone #419 -> crimes: 4615
# Finished with Patrol Zone #420 -> crimes: 2372
# Finished with Patrol Zone #421 -> crimes: 1591
# Finished with Patrol Zone #422 -> crimes: 1854
# Finished with Patrol Zone #423 -> crimes: 2305
# Finished with Patrol Zone #424 -> crimes: 2297
# Finished with Patrol Zone #425 -> crimes: 1606
# Finished with Patrol Zone #426 -> crimes: 921
# Finished with Patrol Zone #427 -> crimes: 1656
# Finished with Patrol Zone #428 -> crimes: 2136
# Finished with Patrol Zone #429 -> crimes: 2097
# Finished with Patrol Zone #430 -> crimes: 702
# Finished with Patrol Zone #431 -> crimes: 1877
# Finished with Patrol Zone #432 -> crimes: 1563
# Finished with Patrol Zone #433 -> crimes: 2647
# Finished with Patrol Zone #434 -> crimes: 1183
# Finished with Patrol Zone #435 -> crimes: 1127
# Finished with Patrol Zone #436 -> crimes: 2737
# Finished with Patrol Zone #437 -> crimes: 1320
# Finished with Patrol Zone #438 -> crimes: 2019
# Finished with Patrol Zone #439 -> crimes: 2429
# Finished with Patrol Zone #440 -> crimes: 2219
# Finished with Patrol Zone #441 -> crimes: 2429
# Finished with Patrol Zone #442 -> crimes: 1872
# Finished with Patrol Zone #443 -> crimes: 1088
# Finished with Patrol Zone #444 -> crimes: 2411
# Finished with Patrol Zone #445 -> crimes: 2088
# Finished with Patrol Zone #446 -> crimes: 1395
# Finished with Patrol Zone #447 -> crimes: 2902
# Finished with Patrol Zone #448 -> crimes: 1851
# Finished with Patrol Zone #449 -> crimes: 3621
# Finished with Patrol Zone #450 -> crimes: 4437
# Finished with Patrol Zone #451 -> crimes: 2178
# Finished with Patrol Zone #452 -> crimes: 1811
# Finished with Patrol Zone #453 -> crimes: 2746
# Finished with Patrol Zone #454 -> crimes: 1008
# Finished with Patrol Zone #455 -> crimes: 2782
# Finished with Patrol Zone #456 -> crimes: 2299
# Finished with Patrol Zone #457 -> crimes: 1381
# Finished with Patrol Zone #458 -> crimes: 3317
# Finished with Patrol Zone #459 -> crimes: 4669
# Finished with Patrol Zone #460 -> crimes: 1202
# Finished with Patrol Zone #461 -> crimes: 1128
# Finished with Patrol Zone #462 -> crimes: 1092
# Finished with Patrol Zone #463 -> crimes: 2365
# Finished with Patrol Zone #464 -> crimes: 3005
# Finished with Patrol Zone #465 -> crimes: 6625
# Finished with Patrol Zone #466 -> crimes: 2592
# Finished with Patrol Zone #467 -> crimes: 6174
# Finished with Patrol Zone #468 -> crimes: 1500
# Finished with Patrol Zone #469 -> crimes: 2584
# Finished with Patrol Zone #470 -> crimes: 2208
# Finished with Patrol Zone #471 -> crimes: 2384
# Finished with Patrol Zone #472 -> crimes: 4812
# Finished with Patrol Zone #473 -> crimes: 2837
# Finished with Patrol Zone #474 -> crimes: 1048
# Finished with Patrol Zone #475 -> crimes: 5873
# Finished with Patrol Zone #476 -> crimes: 1920
# Finished with Patrol Zone #477 -> crimes: 1846
# Finished with Patrol Zone #478 -> crimes: 1271
# Finished with Patrol Zone #479 -> crimes: 3416
# Finished with Patrol Zone #480 -> crimes: 1781
# Finished with Patrol Zone #481 -> crimes: 816
# Finished with Patrol Zone #482 -> crimes: 176
# Finished with Patrol Zone #483 -> crimes: 2105
# Finished with Patrol Zone #484 -> crimes: 1111
# Finished with Patrol Zone #485 -> crimes: 1193
# Finished with Patrol Zone #486 -> crimes: 2419
# Finished with Patrol Zone #487 -> crimes: 3732
# Finished with Patrol Zone #488 -> crimes: 3839
# Finished with Patrol Zone #489 -> crimes: 5336
# Finished with Patrol Zone #490 -> crimes: 1128
# Finished with Patrol Zone #491 -> crimes: 1613
# Finished with Patrol Zone #492 -> crimes: 619
# Finished with Patrol Zone #493 -> crimes: 1636
# Finished with Patrol Zone #494 -> crimes: 2789
# Finished with Patrol Zone #495 -> crimes: 4183
# Finished with Patrol Zone #496 -> crimes: 1591
# Finished with Patrol Zone #497 -> crimes: 2702
# Finished with Patrol Zone #498 -> crimes: 3823
# Finished with Patrol Zone #499 -> crimes: 968
# Finished with Patrol Zone #500 -> crimes: 1655
# Finished with Patrol Zone #501 -> crimes: 1227
# Finished with Patrol Zone #502 -> crimes: 1738
# Finished with Patrol Zone #503 -> crimes: 3057
# Finished with Patrol Zone #504 -> crimes: 4087
# Finished with Patrol Zone #505 -> crimes: 6407
# Finished with Patrol Zone #506 -> crimes: 5392
# Finished with Patrol Zone #507 -> crimes: 2219
# Finished with Patrol Zone #508 -> crimes: 2064
# Finished with Patrol Zone #509 -> crimes: 14561
# Finished with Patrol Zone #510 -> crimes: 3799
# Finished with Patrol Zone #511 -> crimes: 3522
# Finished with Patrol Zone #512 -> crimes: 2992
# Finished with Patrol Zone #513 -> crimes: 5618
# Finished with Patrol Zone #514 -> crimes: 6204
# Finished with Patrol Zone #515 -> crimes: 6069
# Finished with Patrol Zone #516 -> crimes: 3492
# Finished with Patrol Zone #517 -> crimes: 5148
# Finished with Patrol Zone #518 -> crimes: 12795
# Finished with Patrol Zone #519 -> crimes: 11045
# Finished with Patrol Zone #520 -> crimes: 8319
# Finished with Patrol Zone #521 -> crimes: 3519
# Finished with Patrol Zone #522 -> crimes: 3462
# Finished with Patrol Zone #523 -> crimes: 2640
# Finished with Patrol Zone #524 -> crimes: 1424
# Finished with Patrol Zone #525 -> crimes: 1649
# Finished with Patrol Zone #526 -> crimes: 1486
# Finished with Patrol Zone #527 -> crimes: 16049
# Finished with Patrol Zone #528 -> crimes: 4493
# Finished with Patrol Zone #529 -> crimes: 2024
# Finished with Patrol Zone #530 -> crimes: 5000
# Finished with Patrol Zone #531 -> crimes: 3097
# Finished with Patrol Zone #532 -> crimes: 3618
# Finished with Patrol Zone #533 -> crimes: 8987
# Finished with Patrol Zone #534 -> crimes: 2133
# Finished with Patrol Zone #535 -> crimes: 964
# Finished with Patrol Zone #536 -> crimes: 496
# Finished with Patrol Zone #537 -> crimes: 396
# Finished with Patrol Zone #538 -> crimes: 2150
# Finished with Patrol Zone #539 -> crimes: 196
# Finished with Patrol Zone #540 -> crimes: 22989
# Finished with Patrol Zone #541 -> crimes: 10143
# Finished with Patrol Zone #542 -> crimes: 514
# Finished with Patrol Zone #543 -> crimes: 1443
# Finished with Patrol Zone #544 -> crimes: 1634
# Finished with Patrol Zone #545 -> crimes: 4384
# Finished with Patrol Zone #546 -> crimes: 1778
# Finished with Patrol Zone #547 -> crimes: 982
# Finished with Patrol Zone #548 -> crimes: 3000
# Finished with Patrol Zone #549 -> crimes: 3797
# Finished with Patrol Zone #550 -> crimes: 1509
# Finished with Patrol Zone #551 -> crimes: 1652
# Finished with Patrol Zone #552 -> crimes: 3308
# Finished with Patrol Zone #553 -> crimes: 2637
# Finished with Patrol Zone #554 -> crimes: 5672
# Finished with Patrol Zone #555 -> crimes: 8119
# Finished with Patrol Zone #556 -> crimes: 3254
# Finished with Patrol Zone #557 -> crimes: 4110
# Finished with Patrol Zone #558 -> crimes: 861
# Finished with Patrol Zone #559 -> crimes: 1786
# Finished with Patrol Zone #560 -> crimes: 6791
# Finished with Patrol Zone #561 -> crimes: 3058
# Finished with Patrol Zone #562 -> crimes: 4153
# Finished with Patrol Zone #563 -> crimes: 1376
# Finished with Patrol Zone #564 -> crimes: 2987
# Finished with Patrol Zone #565 -> crimes: 5321
# Finished with Patrol Zone #566 -> crimes: 12494
# Finished with Patrol Zone #567 -> crimes: 7597
# Finished with Patrol Zone #568 -> crimes: 3165
# Finished with Patrol Zone #569 -> crimes: 4257
# Finished with Patrol Zone #570 -> crimes: 9852
# Finished with Patrol Zone #571 -> crimes: 6990
# Finished with Patrol Zone #572 -> crimes: 7534
# Finished with Patrol Zone #573 -> crimes: 4863
# Finished with Patrol Zone #574 -> crimes: 5266
# Finished with Patrol Zone #575 -> crimes: 6895
# Finished with Patrol Zone #576 -> crimes: 2586
# Finished with Patrol Zone #577 -> crimes: 535
# Finished with Patrol Zone #578 -> crimes: 2219
# Finished with Patrol Zone #579 -> crimes: 840
# Finished with Patrol Zone #580 -> crimes: 3108
# Finished with Patrol Zone #581 -> crimes: 3276
# Finished with Patrol Zone #582 -> crimes: 3100
# Finished with Patrol Zone #583 -> crimes: 11586
# Finished with Patrol Zone #584 -> crimes: 12027
# Finished with Patrol Zone #585 -> crimes: 3721
# Finished with Patrol Zone #586 -> crimes: 3781
# Finished with Patrol Zone #587 -> crimes: 2024
# Finished with Patrol Zone #588 -> crimes: 1985
# Finished with Patrol Zone #589 -> crimes: 4737
# Finished with Patrol Zone #590 -> crimes: 642
# Finished with Patrol Zone #591 -> crimes: 2205
# Finished with Patrol Zone #592 -> crimes: 642
# Finished with Patrol Zone #593 -> crimes: 1484
# Finished with Patrol Zone #594 -> crimes: 943
# Finished with Patrol Zone #595 -> crimes: 1797
# Finished with Patrol Zone #596 -> crimes: 1639
# Finished with Patrol Zone #597 -> crimes: 7795
# Finished with Patrol Zone #598 -> crimes: 7600
# Finished with Patrol Zone #599 -> crimes: 4605
# Finished with Patrol Zone #600 -> crimes: 887
# Finished with Patrol Zone #601 -> crimes: 5542
# Finished with Patrol Zone #602 -> crimes: 5080
# Finished with Patrol Zone #603 -> crimes: 3811
# Finished with Patrol Zone #604 -> crimes: 3539
# Finished with Patrol Zone #605 -> crimes: 4754
# Finished with Patrol Zone #606 -> crimes: 5859
# Finished with Patrol Zone #607 -> crimes: 4313
# Finished with Patrol Zone #608 -> crimes: 2985
# Finished with Patrol Zone #609 -> crimes: 1704
# Finished with Patrol Zone #610 -> crimes: 7006
# Finished with Patrol Zone #611 -> crimes: 467
# Finished with Patrol Zone #612 -> crimes: 837
# Finished with Patrol Zone #613 -> crimes: 1453
# Finished with Patrol Zone #614 -> crimes: 7463
# Finished with Patrol Zone #615 -> crimes: 2637
# Finished with Patrol Zone #616 -> crimes: 7946
# Finished with Patrol Zone #617 -> crimes: 5523
# Finished with Patrol Zone #618 -> crimes: 3212
# Finished with Patrol Zone #619 -> crimes: 629
# Finished with Patrol Zone #620 -> crimes: 6262
# Finished with Patrol Zone #621 -> crimes: 6558
# Finished with Patrol Zone #622 -> crimes: 9441
# Finished with Patrol Zone #623 -> crimes: 3892
# Finished with Patrol Zone #624 -> crimes: 3918
# Finished with Patrol Zone #625 -> crimes: 9836
# Finished with Patrol Zone #626 -> crimes: 555
# Finished with Patrol Zone #627 -> crimes: 1714
# Finished with Patrol Zone #628 -> crimes: 30
# Finished with Patrol Zone #629 -> crimes: 71
# Finished with Patrol Zone #630 -> crimes: 2355
# Finished with Patrol Zone #631 -> crimes: 22427
# Finished with Patrol Zone #632 -> crimes: 2028
# Finished with Patrol Zone #633 -> crimes: 796
# Finished with Patrol Zone #634 -> crimes: 2244
# Finished with Patrol Zone #635 -> crimes: 1876
# Finished with Patrol Zone #636 -> crimes: 2008
# Finished with Patrol Zone #637 -> crimes: 2371
# Finished with Patrol Zone #638 -> crimes: 984
# Finished with Patrol Zone #639 -> crimes: 673
# Finished with Patrol Zone #640 -> crimes: 2236
# Finished with Patrol Zone #641 -> crimes: 1357
# Finished with Patrol Zone #642 -> crimes: 995
# Finished with Patrol Zone #643 -> crimes: 1340
# Finished with Patrol Zone #644 -> crimes: 2158
# Finished with Patrol Zone #645 -> crimes: 3388
# Finished with Patrol Zone #646 -> crimes: 1054
# Finished with Patrol Zone #647 -> crimes: 2892
# Finished with Patrol Zone #648 -> crimes: 2314
# Finished with Patrol Zone #649 -> crimes: 1983
# Finished with Patrol Zone #650 -> crimes: 3554
# Finished with Patrol Zone #651 -> crimes: 3305
# Finished with Patrol Zone #652 -> crimes: 2406
# Finished with Patrol Zone #653 -> crimes: 3707
# Finished with Patrol Zone #654 -> crimes: 1979
# Finished with Patrol Zone #655 -> crimes: 3037
# Finished with Patrol Zone #656 -> crimes: 1862
# Finished with Patrol Zone #657 -> crimes: 2000
# Finished with Patrol Zone #658 -> crimes: 1536
# Finished with Patrol Zone #659 -> crimes: 2850
# Finished with Patrol Zone #660 -> crimes: 5139
# Finished with Patrol Zone #661 -> crimes: 2848
# Finished with Patrol Zone #662 -> crimes: 3355
# Finished with Patrol Zone #663 -> crimes: 3350
# Finished with Patrol Zone #664 -> crimes: 3570
# Finished with Patrol Zone #665 -> crimes: 1717
# Finished with Patrol Zone #666 -> crimes: 9241
# Finished with Patrol Zone #667 -> crimes: 10009
# Finished with Patrol Zone #668 -> crimes: 7146
# Finished with Patrol Zone #669 -> crimes: 3089
# Finished with Patrol Zone #670 -> crimes: 7678
# Finished with Patrol Zone #671 -> crimes: 3922
# Finished with Patrol Zone #672 -> crimes: 1726
# Finished with Patrol Zone #673 -> crimes: 4630
# Finished with Patrol Zone #674 -> crimes: 3023
# Finished with Patrol Zone #675 -> crimes: 6641
# Finished with Patrol Zone #676 -> crimes: 5652
# Finished with Patrol Zone #677 -> crimes: 1702
# Finished with Patrol Zone #678 -> crimes: 8191
# Finished with Patrol Zone #679 -> crimes: 2391
# Finished with Patrol Zone #680 -> crimes: 6565
# Finished with Patrol Zone #681 -> crimes: 961
# Finished with Patrol Zone #682 -> crimes: 4720
# Finished with Patrol Zone #683 -> crimes: 3931
# Finished with Patrol Zone #684 -> crimes: 3686
# Finished with Patrol Zone #685 -> crimes: 4042
# Finished with Patrol Zone #686 -> crimes: 11620
# Finished with Patrol Zone #687 -> crimes: 930
# Finished with Patrol Zone #688 -> crimes: 324
# Finished with Patrol Zone #689 -> crimes: 2006
# Finished with Patrol Zone #690 -> crimes: 1859
# Finished with Patrol Zone #691 -> crimes: 1324
# Finished with Patrol Zone #692 -> crimes: 1731
# Finished with Patrol Zone #693 -> crimes: 346
# Finished with Patrol Zone #694 -> crimes: 1695
# Finished with Patrol Zone #695 -> crimes: 5010
# Finished with Patrol Zone #696 -> crimes: 4158
# Finished with Patrol Zone #697 -> crimes: 884
# Finished

# %%
print(len(all_crimes_near))
print(all_crimes_near[0])
# Out:
# 698
# [27, 68, 205, 285, 340, 423, 447, 448, 494, 633, 691, 737, 739, 784, 806, 835, 864, 933, 1014, 1022, 1149, 1193, 1212, 1267, 1295, 1301, 1306, 1403, 1462, 1580, 1617, 1765, 1850, 1889, 1921, 1972, 1976, 2027, 2184, 2208, 2226, 2246, 2322, 2399, 2405, 2422, 2495, 2580, 2606, 2611, 2655, 2665, 2675, 2730, 2884, 2897, 2928, 2931, 2960, 3006, 3053, 3115, 3128, 3131, 3142, 3206, 3246, 3451, 3457, 3468, 3491, 3536, 3570, 3645, 3711, 3724, 3749, 3775, 3797, 3854, 3856, 3876, 3969, 4003, 4024, 4161, 4183, 4192, 4203, 4210, 4216, 4231, 4235, 4243, 4270, 4288, 4299, 4338, 4400, 4410, 4450, 4455, 4576, 4648, 4649, 4685, 4750, 4775, 4787, 4801, 4803, 4831, 4836, 4850, 4856, 4877, 4910, 4934, 4945, 4971, 4985, 5100, 5148, 5165, 5188, 5244, 5272, 5313, 5348, 5424, 5436, 5474, 5486, 5499, 5513, 5522, 5707, 5728, 5782, 5844, 5858, 5894, 5930, 6035, 6056, 6141, 6161, 6171, 6178, 6181, 6224, 6550, 6569, 6583, 6587, 6648, 6782, 6811, 6821, 6826, 7025, 7033, 7167, 7229, 7257, 7278, 7280, 7407, 7457, 7463, 7506, 7523, 7531, 7585, 7625, 7663, 7666, 7680, 7722, 7728, 7917, 7934, 7959, 8024, 8119, 8138, 8204, 8272, 8444, 8490, 8521, 8537, 8543, 8563, 8635, 8645, 8851, 8930, 8936, 8949, 8960, 9081, 9095, 9312, 9332, 9357, 9374, 9384, 9447, 9471, 9499, 9525, 9577, 9579, 9677, 9727, 9730, 9839, 9871, 9983, 9995, 10046, 10105, 10122, 10190, 10225, 10271, 10387, 10422, 10438, 10474, 10493, 10601, 10618, 10672, 10676, 10700, 10851, 10862, 10871, 10912, 10953, 11128, 11179, 11196, 11201, 11236, 11294, 11330, 11335, 11363, 11449, 11467, 11617, 11629, 11637, 11663, 11671, 11770, 11823, 11850, 11862, 11933, 11961, 11994, 12001, 12006, 12027, 12047, 12062, 12071, 12092, 12116, 12140, 12174, 12184, 12208, 12228, 12229, 12284, 12310, 12473, 12483, 12566, 12616, 12618, 12681, 12723, 12733, 12744, 12774, 12783, 12799, 12806, 12807, 12848, 12882, 12906, 12936, 12939, 12941, 12946, 12977, 12980, 12999, 13018, 13075, 13088, 13098, 13119, 13171, 13247, 13250, 13292, 13366, 13398, 13461, 13471, 13532, 13657, 13762, 13807, 13809, 13827, 13921, 14044, 14091, 14097, 14235, 14318, 14343, 14371, 14393, 14486, 14604, 14617, 14631, 14667, 14819, 14878, 14893, 14894, 14948, 14951, 14968, 15086, 15290, 15300, 15318, 15333, 15343, 15348, 15351, 15384, 15396, 15418, 15443, 15488, 15499, 15584, 15619, 15680, 15910, 15913, 15916, 15984, 16004, 16069, 16073, 16086, 16191, 16271, 16290, 16309, 16418, 16560, 16567, 16638, 16666, 16671, 16730, 16778, 16796, 16858, 16907, 16940, 17012, 17016, 17058, 17077, 17117, 17137, 17139, 17145, 17283, 17307, 17326, 17405, 17466, 17487, 17528, 17585, 17625, 17681, 17730, 17851, 17874, 17931, 17933, 18039, 18056, 18057, 18111, 18159, 18186, 18197, 18209, 18250, 18338, 18469, 18537, 18621, 18674, 18753, 18817, 18820, 18832, 18915, 18965, 18968, 18994, 19065, 19132, 19228, 19299, 19310, 19367, 19369, 19377, 19381, 19383, 19426, 19451, 19471, 19472, 19484, 19517, 19552, 19710, 19722, 19755, 19776, 19808, 19822, 19855, 19907, 19947, 19969, 19975, 20039, 20049, 20083, 20135, 20144, 20204, 20247, 20289, 20334, 20336, 20363, 20528, 20535, 20581, 20665, 20690, 20802, 20822, 20888, 20924, 20969, 21001, 21078, 21114, 21139, 21170, 21172, 21192, 21216, 21218, 21297, 21310, 21331, 21393, 21476, 21556, 21563, 21582, 21587, 21594, 21628, 21650, 21674, 21716, 21726, 21803, 21822, 21836, 21839, 21966, 21970, 21986, 22004, 22074, 22159, 22193, 22283, 22297, 22324, 22384, 22387, 22433, 22440, 22449, 22497, 22521, 22541, 22560, 22589, 22657, 22694, 22787, 22937, 22945, 22981, 23066, 23067, 23087, 23102, 23104, 23142, 23171, 23206, 23224, 23272, 23281, 23295, 23298, 23306, 23340, 23384, 23409, 23425, 23471, 23474, 23500, 23535, 23676, 23741, 23759, 23877, 23889, 23892, 23938, 23984, 24023, 24105, 24135, 24166, 24201, 24304, 24350, 24431, 24450, 24503, 24583, 24823, 24836, 24868, 24944, 25035, 25042, 25054, 25065, 25193, 25224, 25260, 25296, 25314, 25516, 25559, 25568, 25591, 25613, 25633, 25678, 25679, 25728, 25730, 25840, 26014, 26055, 26063, 26114, 26118, 26124, 26205 ...

# %%
# Creating a CSV with all the crimes reported per Patrol Zone for backup
backup_all_crimes_near = pd.DataFrame({'patrol_zone_index': range(len(all_crimes_near)), 'crimes_near':all_crimes_near})
backup_all_crimes_near.head()
# Out:
#    patrol_zone_index                                        crimes_near
# 0                  0  [27, 68, 205, 285, 340, 423, 447, 448, 494, 63...
# 1                  1  [8, 23, 49, 71, 184, 201, 206, 249, 269, 314, ...
# 2                  2  [96, 458, 633, 691, 854, 864, 925, 933, 950, 1...
# 3                  3  [75, 139, 158, 170, 273, 313, 358, 425, 435, 4...
# 4                  4  [10, 75, 139, 158, 170, 273, 313, 358, 425, 43...

# %%
#Exporting clean dataset version 1 of Zonas de Patrullaje
fileExport = path.join("..","Clean","after_transform","transformed_crimes_near_patrol_Zones.csv")
backup_all_crimes_near.to_csv(fileExport, sep=';', index=False)

# %%
#Checking the exported file
exportFile_df = pd.read_csv(fileExport, sep=';')

exportFile_df.head()
# Out:
#    patrol_zone_index                                        crimes_near
# 0                  0  [27, 68, 205, 285, 340, 423, 447, 448, 494, 63...
# 1                  1  [8, 23, 49, 71, 184, 201, 206, 249, 269, 314, ...
# 2                  2  [96, 458, 633, 691, 854, 864, 925, 933, 950, 1...
# 3                  3  [75, 139, 158, 170, 273, 313, 358, 425, 435, 4...
# 4                  4  [10, 75, 139, 158, 170, 273, 313, 358, 425, 43...

# %%
# Separating each row's crimes list (from all_crimes_near) to have a single pair of Crime_index & patrol_zone_index per row
# This is the data that is going to populate the mysql database table called "delitos_zonas_patrullaje"
crime_pair = list()
patrol_pair = list()

for index in range(len(all_crimes_near)):
    for crime_index in all_crimes_near[index]:
        crime_pair.append(crime_index)
        patrol_pair.append(index)
    print(f"Finished separating Patrol Zone {index}'s crimes'")
print(len(crime_pair))
# Out:
# Finished separating Patrol Zone 0's crimes'
# Finished separating Patrol Zone 1's crimes'
# Finished separating Patrol Zone 2's crimes'
# Finished separating Patrol Zone 3's crimes'
# Finished separating Patrol Zone 4's crimes'
# Finished separating Patrol Zone 5's crimes'
# Finished separating Patrol Zone 6's crimes'
# Finished separating Patrol Zone 7's crimes'
# Finished separating Patrol Zone 8's crimes'
# Finished separating Patrol Zone 9's crimes'
# Finished separating Patrol Zone 10's crimes'
# Finished separating Patrol Zone 11's crimes'
# Finished separating Patrol Zone 12's crimes'
# Finished separating Patrol Zone 13's crimes'
# Finished separating Patrol Zone 14's crimes'
# Finished separating Patrol Zone 15's crimes'
# Finished separating Patrol Zone 16's crimes'
# Finished separating Patrol Zone 17's crimes'
# Finished separating Patrol Zone 18's crimes'
# Finished separating Patrol Zone 19's crimes'
# Finished separating Patrol Zone 20's crimes'
# Finished separating Patrol Zone 21's crimes'
# Finished separating Patrol Zone 22's crimes'
# Finished separating Patrol Zone 23's crimes'
# Finished separating Patrol Zone 24's crimes'
# Finished separating Patrol Zone 25's crimes'
# Finished separating Patrol Zone 26's crimes'
# Finished separating Patrol Zone 27's crimes'
# Finished separating Patrol Zone 28's crimes'
# Finished separating Patrol Zone 29's crimes'
# Finished separating Patrol Zone 30's crimes'
# Finished separating Patrol Zone 31's crimes'
# Finished separating Patrol Zone 32's crimes'
# Finished separating Patrol Zone 33's crimes'
# Finished separating Patrol Zone 34's crimes'
# Finished separating Patrol Zone 35's crimes'
# Finished separating Patrol Zone 36's crimes'
# Finished separating Patrol Zone 37's crimes'
# Finished separating Patrol Zone 38's crimes'
# Finished separating Patrol Zone 39's crimes'
# Finished separating Patrol Zone 40's crimes'
# Finished separating Patrol Zone 41's crimes'
# Finished separating Patrol Zone 42's crimes'
# Finished separating Patrol Zone 43's crimes'
# Finished separating Patrol Zone 44's crimes'
# Finished separating Patrol Zone 45's crimes'
# Finished separating Patrol Zone 46's crimes'
# Finished separating Patrol Zone 47's crimes'
# Finished separating Patrol Zone 48's crimes'
# Finished separating Patrol Zone 49's crimes'
# Finished separating Patrol Zone 50's crimes'
# Finished separating Patrol Zone 51's crimes'
# Finished separating Patrol Zone 52's crimes'
# Finished separating Patrol Zone 53's crimes'
# Finished separating Patrol Zone 54's crimes'
# Finished separating Patrol Zone 55's crimes'
# Finished separating Patrol Zone 56's crimes'
# Finished separating Patrol Zone 57's crimes'
# Finished separating Patrol Zone 58's crimes'
# Finished separating Patrol Zone 59's crimes'
# Finished separating Patrol Zone 60's crimes'
# Finished separating Patrol Zone 61's crimes'
# Finished separating Patrol Zone 62's crimes'
# Finished separating Patrol Zone 63's crimes'
# Finished separating Patrol Zone 64's crimes'
# Finished separating Patrol Zone 65's crimes'
# Finished separating Patrol Zone 66's crimes'
# Finished separating Patrol Zone 67's crimes'
# Finished separating Patrol Zone 68's crimes'
# Finished separating Patrol Zone 69's crimes'
# Finished separating Patrol Zone 70's crimes'
# Finished separating Patrol Zone 71's crimes'
# Finished separating Patrol Zone 72's crimes'
# Finished separating Patrol Zone 73's crimes'
# Finished separating Patrol Zone 74's crimes'
# Finished separating Patrol Zone 75's crimes'
# Finished separating Patrol Zone 76's crimes'
# Finished separating Patrol Zone 77's crimes'
# Finished separating Patrol Zone 78's crimes'
# Finished separating Patrol Zone 79's crimes'
# Finished separating Patrol Zone 80's crimes'
# Finished separating Patrol Zone 81's crimes'
# Finished separating Patrol Zone 82's crimes'
# Finished separating Patrol Zone 83's crimes'
# Finished separating Patrol Zone 84's crimes'
# Finished separating Patrol Zone 85's crimes'
# Finished separating Patrol Zone 86's crimes'
# Finished separating Patrol Zone 87's crimes'
# Finished separating Patrol Zone 88's crimes'
# Finished separating Patrol Zone 89's crimes'
# Finished separating Patrol Zone 90's crimes'
# Finished separating Patrol Zone 91's crimes'
# Finished separating Patrol Zone 92's crimes'
# Finished separating Patrol Zone 93's crimes'
# Finished separating Patrol Zone 94's crimes'
# Finished separating Patrol Zone 95's crimes'
# Finished separating Patrol Zone 96's crimes'
# Finished separating Patrol Zone 97's crimes'
# Finished separating Patrol Zone 98's crimes'
# Finished separating Patrol Zone 99's crimes'
# Finished separating Patrol Zone 100's crimes'
# Finished separating Patrol Zone 101's crimes'
# Finished separating Patrol Zone 102's crimes'
# Finished separating Patrol Zone 103's crimes'
# Finished separating Patrol Zone 104's crimes'
# Finished separating Patrol Zone 105's crimes'
# Finished separating Patrol Zone 106's crimes'
# Finished separating Patrol Zone 107's crimes'
# Finished separating Patrol Zone 108's crimes'
# Finished separating Patrol Zone 109's crimes'
# Finished separating Patrol Zone 110's crimes'
# Finished separating Patrol Zone 111's crimes'
# Finished separating Patrol Zone 112's crimes'
# Finished separating Patrol Zone 113's crimes'
# Finished separating Patrol Zone 114's crimes'
# Finished separating Patrol Zone 115's crimes'
# Finished separating Patrol Zone 116's crimes'
# Finished separating Patrol Zone 117's crimes'
# Finished separating Patrol Zone 118's crimes'
# Finished separating Patrol Zone 119's crimes'
# Finished separating Patrol Zone 120's crimes'
# Finished separating Patrol Zone 121's crimes'
# Finished separating Patrol Zone 122's crimes'
# Finished separating Patrol Zone 123's crimes'
# Finished separating Patrol Zone 124's crimes'
# Finished separating Patrol Zone 125's crimes'
# Finished separating Patrol Zone 126's crimes'
# Finished separating Patrol Zone 127's crimes'
# Finished separating Patrol Zone 128's crimes'
# Finished separating Patrol Zone 129's crimes'
# Finished separating Patrol Zone 130's crimes'
# Finished separating Patrol Zone 131's crimes'
# Finished separating Patrol Zone 132's crimes'
# Finished separating Patrol Zone 133's crimes'
# Finished separating Patrol Zone 134's crimes'
# Finished separating Patrol Zone 135's crimes'
# Finished separating Patrol Zone 136's crimes'
# Finished separating Patrol Zone 137's crimes'
# Finished separating Patrol Zone 138's crimes'
# Finished separating Patrol Zone 139's crimes'
# Finished separating Patrol Zone 140's crimes'
# Finished separating Patrol Zone 141's crimes'
# Finished separating Patrol Zone 142's crimes'
# Finished separating Patrol Zone 143's crimes'
# Finished separating Patrol Zone 144's crimes'
# Finished separating Patrol Zone 145's crimes'
# Finished separating Patrol Zone 146's crimes'
# Finished separating Patrol Zone 147's crimes'
# Finished separating Patrol Zone 148's crimes'
# Finished separating Patrol Zone 149's crimes'
# Finished separating Patrol Zone 150's crimes'
# Finished separating Patrol Zone 151's crimes'
# Finished separating Patrol Zone 152's crimes'
# Finished separating Patrol Zone 153's crimes'
# Finished separating Patrol Zone 154's crimes'
# Finished separating Patrol Zone 155's crimes'
# Finished separating Patrol Zone 156's crimes'
# Finished separating Patrol Zone 157's crimes'
# Finished separating Patrol Zone 158's crimes'
# Finished separating Patrol Zone 159's crimes'
# Finished separating Patrol Zone 160's crimes'
# Finished separating Patrol Zone 161's crimes'
# Finished separating Patrol Zone 162's crimes'
# Finished separating Patrol Zone 163's crimes'
# Finished separating Patrol Zone 164's crimes'
# Finished separating Patrol Zone 165's crimes'
# Finished separating Patrol Zone 166's crimes'
# Finished separating Patrol Zone 167's crimes'
# Finished separating Patrol Zone 168's crimes'
# Finished separating Patrol Zone 169's crimes'
# Finished separating Patrol Zone 170's crimes'
# Finished separating Patrol Zone 171's crimes'
# Finished separating Patrol Zone 172's crimes'
# Finished separating Patrol Zone 173's crimes'
# Finished separating Patrol Zone 174's crimes'
# Finished separating Patrol Zone 175's crimes'
# Finished separating Patrol Zone 176's crimes'
# Finished separating Patrol Zone 177's crimes'
# Finished separating Patrol Zone 178's crimes'
# Finished separating Patrol Zone 179's crimes'
# Finished separating Patrol Zone 180's crimes'
# Finished separating Patrol Zone 181's crimes'
# Finished separating Patrol Zone 182's crimes'
# Finished separating Patrol Zone 183's crimes'
# Finished separating Patrol Zone 184's crimes'
# Finished separating Patrol Zone 185's crimes'
# Finished separating Patrol Zone 186's crimes'
# Finished separating Patrol Zone 187's crimes'
# Finished separating Patrol Zone 188's crimes'
# Finished separating Patrol Zone 189's crimes'
# Finished separating Patrol Zone 190's crimes'
# Finished separating Patrol Zone 191's crimes'
# Finished separating Patrol Zone 192's crimes'
# Finished separating Patrol Zone 193's crimes'
# Finished separating Patrol Zone 194's crimes'
# Finished separating Patrol Zone 195's crimes'
# Finished separating Patrol Zone 196's crimes'
# Finished separating Patrol Zone 197's crimes'
# Finished separating Patrol Zone 198's crimes'
# Finished separating Patrol Zone 199's crimes'
# Finished separating Patrol Zone 200's crimes'
# Finished separating Patrol Zone 201's crimes'
# Finished separating Patrol Zone 202's crimes'
# Finished separating Patrol Zone 203's crimes'
# Finished separating Patrol Zone 204's crimes'
# Finished separating Patrol Zone 205's crimes'
# Finished separating Patrol Zone 206's crimes'
# Finished separating Patrol Zone 207's crimes'
# Finished separating Patrol Zone 208's crimes'
# Finished separating Patrol Zone 209's crimes'
# Finished separating Patrol Zone 210's crimes'
# Finished separating Patrol Zone 211's crimes'
# Finished separating Patrol Zone 212's crimes'
# Finished separating Patrol Zone 213's crimes'
# Finished separating Patrol Zone 214's crimes'
# Finished separating Patrol Zone 215's crimes'
# Finished separating Patrol Zone 216's crimes'
# Finished separating Patrol Zone 217's crimes'
# Finished separating Patrol Zone 218's crimes'
# Finished separating Patrol Zone 219's crimes'
# Finished separating Patrol Zone 220's crimes'
# Finished separating Patrol Zone 221's crimes'
# Finished separating Patrol Zone 222's crimes'
# Finished separating Patrol Zone 223's crimes'
# Finished separating Patrol Zone 224's crimes'
# Finished separating Patrol Zone 225's crimes'
# Finished separating Patrol Zone 226's crimes'
# Finished separating Patrol Zone 227's crimes'
# Finished separating Patrol Zone 228's crimes'
# Finished separating Patrol Zone 229's crimes'
# Finished separating Patrol Zone 230's crimes'
# Finished separating Patrol Zone 231's crimes'
# Finished separating Patrol Zone 232's crimes'
# Finished separating Patrol Zone 233's crimes'
# Finished separating Patrol Zone 234's crimes'
# Finished separating Patrol Zone 235's crimes'
# Finished separating Patrol Zone 236's crimes'
# Finished separating Patrol Zone 237's crimes'
# Finished separating Patrol Zone 238's crimes'
# Finished separating Patrol Zone 239's crimes'
# Finished separating Patrol Zone 240's crimes'
# Finished separating Patrol Zone 241's crimes'
# Finished separating Patrol Zone 242's crimes'
# Finished separating Patrol Zone 243's crimes'
# Finished separating Patrol Zone 244's crimes'
# Finished separating Patrol Zone 245's crimes'
# Finished separating Patrol Zone 246's crimes'
# Finished separating Patrol Zone 247's crimes'
# Finished separating Patrol Zone 248's crimes'
# Finished separating Patrol Zone 249's crimes'
# Finished separating Patrol Zone 250's crimes'
# Finished separating Patrol Zone 251's crimes'
# Finished separating Patrol Zone 252's crimes'
# Finished separating Patrol Zone 253's crimes'
# Finished separating Patrol Zone 254's crimes'
# Finished separating Patrol Zone 255's crimes'
# Finished separating Patrol Zone 256's crimes'
# Finished separating Patrol Zone 257's crimes'
# Finished separating Patrol Zone 258's crimes'
# Finished separating Patrol Zone 259's crimes'
# Finished separating Patrol Zone 260's crimes'
# Finished separating Patrol Zone 261's crimes'
# Finished separating Patrol Zone 262's crimes'
# Finished separating Patrol Zone 263's crimes'
# Finished separating Patrol Zone 264's crimes'
# Finished separating Patrol Zone 265's crimes'
# Finished separating Patrol Zone 266's crimes'
# Finished separating Patrol Zone 267's crimes'
# Finished separating Patrol Zone 268's crimes'
# Finished separating Patrol Zone 269's crimes'
# Finished separating Patrol Zone 270's crimes'
# Finished separating Patrol Zone 271's crimes'
# Finished separating Patrol Zone 272's crimes'
# Finished separating Patrol Zone 273's crimes'
# Finished separating Patrol Zone 274's crimes'
# Finished separating Patrol Zone 275's crimes'
# Finished separating Patrol Zone 276's crimes'
# Finished separating Patrol Zone 277's crimes'
# Finished separating Patrol Zone 278's crimes'
# Finished separating Patrol Zone 279's crimes'
# Finished separating Patrol Zone 280's crimes'
# Finished separating Patrol Zone 281's crimes'
# Finished separating Patrol Zone 282's crimes'
# Finished separating Patrol Zone 283's crimes'
# Finished separating Patrol Zone 284's crimes'
# Finished separating Patrol Zone 285's crimes'
# Finished separating Patrol Zone 286's crimes'
# Finished separating Patrol Zone 287's crimes'
# Finished separating Patrol Zone 288's crimes'
# Finished separating Patrol Zone 289's crimes'
# Finished separating Patrol Zone 290's crimes'
# Finished separating Patrol Zone 291's crimes'
# Finished separating Patrol Zone 292's crimes'
# Finished separating Patrol Zone 293's crimes'
# Finished separating Patrol Zone 294's crimes'
# Finished separating Patrol Zone 295's crimes'
# Finished separating Patrol Zone 296's crimes'
# Finished separating Patrol Zone 297's crimes'
# Finished separating Patrol Zone 298's crimes'
# Finished separating Patrol Zone 299's crimes'
# Finished separating Patrol Zone 300's crimes'
# Finished separating Patrol Zone 301's crimes'
# Finished separating Patrol Zone 302's crimes'
# Finished separating Patrol Zone 303's crimes'
# Finished separating Patrol Zone 304's crimes'
# Finished separating Patrol Zone 305's crimes'
# Finished separating Patrol Zone 306's crimes'
# Finished separating Patrol Zone 307's crimes'
# Finished separating Patrol Zone 308's crimes'
# Finished separating Patrol Zone 309's crimes'
# Finished separating Patrol Zone 310's crimes'
# Finished separating Patrol Zone 311's crimes'
# Finished separating Patrol Zone 312's crimes'
# Finished separating Patrol Zone 313's crimes'
# Finished separating Patrol Zone 314's crimes'
# Finished separating Patrol Zone 315's crimes'
# Finished separating Patrol Zone 316's crimes'
# Finished separating Patrol Zone 317's crimes'
# Finished separating Patrol Zone 318's crimes'
# Finished separating Patrol Zone 319's crimes'
# Finished separating Patrol Zone 320's crimes'
# Finished separating Patrol Zone 321's crimes'
# Finished separating Patrol Zone 322's crimes'
# Finished separating Patrol Zone 323's crimes'
# Finished separating Patrol Zone 324's crimes'
# Finished separating Patrol Zone 325's crimes'
# Finished separating Patrol Zone 326's crimes'
# Finished separating Patrol Zone 327's crimes'
# Finished separating Patrol Zone 328's crimes'
# Finished separating Patrol Zone 329's crimes'
# Finished separating Patrol Zone 330's crimes'
# Finished separating Patrol Zone 331's crimes'
# Finished separating Patrol Zone 332's crimes'
# Finished separating Patrol Zone 333's crimes'
# Finished separating Patrol Zone 334's crimes'
# Finished separating Patrol Zone 335's crimes'
# Finished separating Patrol Zone 336's crimes'
# Finished separating Patrol Zone 337's crimes'
# Finished separating Patrol Zone 338's crimes'
# Finished separating Patrol Zone 339's crimes'
# Finished separating Patrol Zone 340's crimes'
# Finished separating Patrol Zone 341's crimes'
# Finished separating Patrol Zone 342's crimes'
# Finished separating Patrol Zone 343's crimes'
# Finished separating Patrol Zone 344's crimes'
# Finished separating Patrol Zone 345's crimes'
# Finished separating Patrol Zone 346's crimes'
# Finished separating Patrol Zone 347's crimes'
# Finished separating Patrol Zone 348's crimes'
# Finished separating Patrol Zone 349's crimes'
# Finished separating Patrol Zone 350's crimes'
# Finished separating Patrol Zone 351's crimes'
# Finished separating Patrol Zone 352's crimes'
# Finished separating Patrol Zone 353's crimes'
# Finished separating Patrol Zone 354's crimes'
# Finished separating Patrol Zone 355's crimes'
# Finished separating Patrol Zone 356's crimes'
# Finished separating Patrol Zone 357's crimes'
# Finished separating Patrol Zone 358's crimes'
# Finished separating Patrol Zone 359's crimes'
# Finished separating Patrol Zone 360's crimes'
# Finished separating Patrol Zone 361's crimes'
# Finished separating Patrol Zone 362's crimes'
# Finished separating Patrol Zone 363's crimes'
# Finished separating Patrol Zone 364's crimes'
# Finished separating Patrol Zone 365's crimes'
# Finished separating Patrol Zone 366's crimes'
# Finished separating Patrol Zone 367's crimes'
# Finished separating Patrol Zone 368's crimes'
# Finished separating Patrol Zone 369's crimes'
# Finished separating Patrol Zone 370's crimes'
# Finished separating Patrol Zone 371's crimes'
# Finished separating Patrol Zone 372's crimes'
# Finished separating Patrol Zone 373's crimes'
# Finished separating Patrol Zone 374's crimes'
# Finished separating Patrol Zone 375's crimes'
# Finished separating Patrol Zone 376's crimes'
# Finished separating Patrol Zone 377's crimes'
# Finished separating Patrol Zone 378's crimes'
# Finished separating Patrol Zone 379's crimes'
# Finished separating Patrol Zone 380's crimes'
# Finished separating Patrol Zone 381's crimes'
# Finished separating Patrol Zone 382's crimes'
# Finished separating Patrol Zone 383's crimes'
# Finished separating Patrol Zone 384's crimes'
# Finished separating Patrol Zone 385's crimes'
# Finished separating Patrol Zone 386's crimes'
# Finished separating Patrol Zone 387's crimes'
# Finished separating Patrol Zone 388's crimes'
# Finished separating Patrol Zone 389's crimes'
# Finished separating Patrol Zone 390's crimes'
# Finished separating Patrol Zone 391's crimes'
# Finished separating Patrol Zone 392's crimes'
# Finished separating Patrol Zone 393's crimes'
# Finished separating Patrol Zone 394's crimes'
# Finished separating Patrol Zone 395's crimes'
# Finished separating Patrol Zone 396's crimes'
# Finished separating Patrol Zone 397's crimes'
# Finished separating Patrol Zone 398's crimes'
# Finished separating Patrol Zone 399's crimes'
# Finished separating Patrol Zone 400's crimes'
# Finished separating Patrol Zone 401's crimes'
# Finished separating Patrol Zone 402's crimes'
# Finished separating Patrol Zone 403's crimes'
# Finished separating Patrol Zone 404's crimes'
# Finished separating Patrol Zone 405's crimes'
# Finished separating Patrol Zone 406's crimes'
# Finished separating Patrol Zone 407's crimes'
# Finished separating Patrol Zone 408's crimes'
# Finished separating Patrol Zone 409's crimes'
# Finished separating Patrol Zone 410's crimes'
# Finished separating Patrol Zone 411's crimes'
# Finished separating Patrol Zone 412's crimes'
# Finished separating Patrol Zone 413's crimes'
# Finished separating Patrol Zone 414's crimes'
# Finished separating Patrol Zone 415's crimes'
# Finished separating Patrol Zone 416's crimes'
# Finished separating Patrol Zone 417's crimes'
# Finished separating Patrol Zone 418's crimes'
# Finished separating Patrol Zone 419's crimes'
# Finished separating Patrol Zone 420's crimes'
# Finished separating Patrol Zone 421's crimes'
# Finished separating Patrol Zone 422's crimes'
# Finished separating Patrol Zone 423's crimes'
# Finished separating Patrol Zone 424's crimes'
# Finished separating Patrol Zone 425's crimes'
# Finished separating Patrol Zone 426's crimes'
# Finished separating Patrol Zone 427's crimes'
# Finished separating Patrol Zone 428's crimes'
# Finished separating Patrol Zone 429's crimes'
# Finished separating Patrol Zone 430's crimes'
# Finished separating Patrol Zone 431's crimes'
# Finished separating Patrol Zone 432's crimes'
# Finished separating Patrol Zone 433's crimes'
# Finished separating Patrol Zone 434's crimes'
# Finished separating Patrol Zone 435's crimes'
# Finished separating Patrol Zone 436's crimes'
# Finished separating Patrol Zone 437's crimes'
# Finished separating Patrol Zone 438's crimes'
# Finished separating Patrol Zone 439's crimes'
# Finished separating Patrol Zone 440's crimes'
# Finished separating Patrol Zone 441's crimes'
# Finished separating Patrol Zone 442's crimes'
# Finished separating Patrol Zone 443's crimes'
# Finished separating Patrol Zone 444's crimes'
# Finished separating Patrol Zone 445's crimes'
# Finished separating Patrol Zone 446's crimes'
# Finished separating Patrol Zone 447's crimes'
# Finished separating Patrol Zone 448's crimes'
# Finished separating Patrol Zone 449's crimes'
# Finished separating Patrol Zone 450's crimes'
# Finished separating Patrol Zone 451's crimes'
# Finished separating Patrol Zone 452's crimes'
# Finished separating Patrol Zone 453's crimes'
# Finished separating Patrol Zone 454's crimes'
# Finished separating Patrol Zone 455's crimes'
# Finished separating Patrol Zone 456's crimes'
# Finished separating Patrol Zone 457's crimes'
# Finished separating Patrol Zone 458's crimes'
# Finished separating Patrol Zone 459's crimes'
# Finished separating Patrol Zone 460's crimes'
# Finished separating Patrol Zone 461's crimes'
# Finished separating Patrol Zone 462's crimes'
# Finished separating Patrol Zone 463's crimes'
# Finished separating Patrol Zone 464's crimes'
# Finished separating Patrol Zone 465's crimes'
# Finished separating Patrol Zone 466's crimes'
# Finished separating Patrol Zone 467's crimes'
# Finished separating Patrol Zone 468's crimes'
# Finished separating Patrol Zone 469's crimes'
# Finished separating Patrol Zone 470's crimes'
# Finished separating Patrol Zone 471's crimes'
# Finished separating Patrol Zone 472's crimes'
# Finished separating Patrol Zone 473's crimes'
# Finished separating Patrol Zone 474's crimes'
# Finished separating Patrol Zone 475's crimes'
# Finished separating Patrol Zone 476's crimes'
# Finished separating Patrol Zone 477's crimes'
# Finished separating Patrol Zone 478's crimes'
# Finished separating Patrol Zone 479's crimes'
# Finished separating Patrol Zone 480's crimes'
# Finished separating Patrol Zone 481's crimes'
# Finished separating Patrol Zone 482's crimes'
# Finished separating Patrol Zone 483's crimes'
# Finished separating Patrol Zone 484's crimes'
# Finished separating Patrol Zone 485's crimes'
# Finished separating Patrol Zone 486's crimes'
# Finished separating Patrol Zone 487's crimes'
# Finished separating Patrol Zone 488's crimes'
# Finished separating Patrol Zone 489's crimes'
# Finished separating Patrol Zone 490's crimes'
# Finished separating Patrol Zone 491's crimes'
# Finished separating Patrol Zone 492's crimes'
# Finished separating Patrol Zone 493's crimes'
# Finished separating Patrol Zone 494's crimes'
# Finished separating Patrol Zone 495's crimes'
# Finished separating Patrol Zone 496's crimes'
# Finished separating Patrol Zone 497's crimes'
# Finished separating Patrol Zone 498's crimes'
# Finished separating Patrol Zone 499's crimes'
# Finished separating Patrol Zone 500's crimes'
# Finished separating Patrol Zone 501's crimes'
# Finished separating Patrol Zone 502's crimes'
# Finished separating Patrol Zone 503's crimes'
# Finished separating Patrol Zone 504's crimes'
# Finished separating Patrol Zone 505's crimes'
# Finished separating Patrol Zone 506's crimes'
# Finished separating Patrol Zone 507's crimes'
# Finished separating Patrol Zone 508's crimes'
# Finished separating Patrol Zone 509's crimes'
# Finished separating Patrol Zone 510's crimes'
# Finished separating Patrol Zone 511's crimes'
# Finished separating Patrol Zone 512's crimes'
# Finished separating Patrol Zone 513's crimes'
# Finished separating Patrol Zone 514's crimes'
# Finished separating Patrol Zone 515's crimes'
# Finished separating Patrol Zone 516's crimes'
# Finished separating Patrol Zone 517's crimes'
# Finished separating Patrol Zone 518's crimes'
# Finished separating Patrol Zone 519's crimes'
# Finished separating Patrol Zone 520's crimes'
# Finished separating Patrol Zone 521's crimes'
# Finished separating Patrol Zone 522's crimes'
# Finished separating Patrol Zone 523's crimes'
# Finished separating Patrol Zone 524's crimes'
# Finished separating Patrol Zone 525's crimes'
# Finished separating Patrol Zone 526's crimes'
# Finished separating Patrol Zone 527's crimes'
# Finished separating Patrol Zone 528's crimes'
# Finished separating Patrol Zone 529's crimes'
# Finished separating Patrol Zone 530's crimes'
# Finished separating Patrol Zone 531's crimes'
# Finished separating Patrol Zone 532's crimes'
# Finished separating Patrol Zone 533's crimes'
# Finished separating Patrol Zone 534's crimes'
# Finished separating Patrol Zone 535's crimes'
# Finished separating Patrol Zone 536's crimes'
# Finished separating Patrol Zone 537's crimes'
# Finished separating Patrol Zone 538's crimes'
# Finished separating Patrol Zone 539's crimes'
# Finished separating Patrol Zone 540's crimes'
# Finished separating Patrol Zone 541's crimes'
# Finished separating Patrol Zone 542's crimes'
# Finished separating Patrol Zone 543's crimes'
# Finished separating Patrol Zone 544's crimes'
# Finished separating Patrol Zone 545's crimes'
# Finished separating Patrol Zone 546's crimes'
# Finished separating Patrol Zone 547's crimes'
# Finished separating Patrol Zone 548's crimes'
# Finished separating Patrol Zone 549's crimes'
# Finished separating Patrol Zone 550's crimes'
# Finished separating Patrol Zone 551's crimes'
# Finished separating Patrol Zone 552's crimes'
# Finished separating Patrol Zone 553's crimes'
# Finished separating Patrol Zone 554's crimes'
# Finished separating Patrol Zone 555's crimes'
# Finished separating Patrol Zone 556's crimes'
# Finished separating Patrol Zone 557's crimes'
# Finished separating Patrol Zone 558's crimes'
# Finished separating Patrol Zone 559's crimes'
# Finished separating Patrol Zone 560's crimes'
# Finished separating Patrol Zone 561's crimes'
# Finished separating Patrol Zone 562's crimes'
# Finished separating Patrol Zone 563's crimes'
# Finished separating Patrol Zone 564's crimes'
# Finished separating Patrol Zone 565's crimes'
# Finished separating Patrol Zone 566's crimes'
# Finished separating Patrol Zone 567's crimes'
# Finished separating Patrol Zone 568's crimes'
# Finished separating Patrol Zone 569's crimes'
# Finished separating Patrol Zone 570's crimes'
# Finished separating Patrol Zone 571's crimes'
# Finished separating Patrol Zone 572's crimes'
# Finished separating Patrol Zone 573's crimes'
# Finished separating Patrol Zone 574's crimes'
# Finished separating Patrol Zone 575's crimes'
# Finished separating Patrol Zone 576's crimes'
# Finished separating Patrol Zone 577's crimes'
# Finished separating Patrol Zone 578's crimes'
# Finished separating Patrol Zone 579's crimes'
# Finished separating Patrol Zone 580's crimes'
# Finished separating Patrol Zone 581's crimes'
# Finished separating Patrol Zone 582's crimes'
# Finished separating Patrol Zone 583's crimes'
# Finished separating Patrol Zone 584's crimes'
# Finished separating Patrol Zone 585's crimes'
# Finished separating Patrol Zone 586's crimes'
# Finished separating Patrol Zone 587's crimes'
# Finished separating Patrol Zone 588's crimes'
# Finished separating Patrol Zone 589's crimes'
# Finished separating Patrol Zone 590's crimes'
# Finished separating Patrol Zone 591's crimes'
# Finished separating Patrol Zone 592's crimes'
# Finished separating Patrol Zone 593's crimes'
# Finished separating Patrol Zone 594's crimes'
# Finished separating Patrol Zone 595's crimes'
# Finished separating Patrol Zone 596's crimes'
# Finished separating Patrol Zone 597's crimes'
# Finished separating Patrol Zone 598's crimes'
# Finished separating Patrol Zone 599's crimes'
# Finished separating Patrol Zone 600's crimes'
# Finished separating Patrol Zone 601's crimes'
# Finished separating Patrol Zone 602's crimes'
# Finished separating Patrol Zone 603's crimes'
# Finished separating Patrol Zone 604's crimes'
# Finished separating Patrol Zone 605's crimes'
# Finished separating Patrol Zone 606's crimes'
# Finished separating Patrol Zone 607's crimes'
# Finished separating Patrol Zone 608's crimes'
# Finished separating Patrol Zone 609's crimes'
# Finished separating Patrol Zone 610's crimes'
# Finished separating Patrol Zone 611's crimes'
# Finished separating Patrol Zone 612's crimes'
# Finished separating Patrol Zone 613's crimes'
# Finished separating Patrol Zone 614's crimes'
# Finished separating Patrol Zone 615's crimes'
# Finished separating Patrol Zone 616's crimes'
# Finished separating Patrol Zone 617's crimes'
# Finished separating Patrol Zone 618's crimes'
# Finished separating Patrol Zone 619's crimes'
# Finished separating Patrol Zone 620's crimes'
# Finished separating Patrol Zone 621's crimes'
# Finished separating Patrol Zone 622's crimes'
# Finished separating Patrol Zone 623's crimes'
# Finished separating Patrol Zone 624's crimes'
# Finished separating Patrol Zone 625's crimes'
# Finished separating Patrol Zone 626's crimes'
# Finished separating Patrol Zone 627's crimes'
# Finished separating Patrol Zone 628's crimes'
# Finished separating Patrol Zone 629's crimes'
# Finished separating Patrol Zone 630's crimes'
# Finished separating Patrol Zone 631's crimes'
# Finished separating Patrol Zone 632's crimes'
# Finished separating Patrol Zone 633's crimes'
# Finished separating Patrol Zone 634's crimes'
# Finished separating Patrol Zone 635's crimes'
# Finished separating Patrol Zone 636's crimes'
# Finished separating Patrol Zone 637's crimes'
# Finished separating Patrol Zone 638's crimes'
# Finished separating Patrol Zone 639's crimes'
# Finished separating Patrol Zone 640's crimes'
# Finished separating Patrol Zone 641's crimes'
# Finished separating Patrol Zone 642's crimes'
# Finished separating Patrol Zone 643's crimes'
# Finished separating Patrol Zone 644's crimes'
# Finished separating Patrol Zone 645's crimes'
# Finished separating Patrol Zone 646's crimes'
# Finished separating Patrol Zone 647's crimes'
# Finished separating Patrol Zone 648's crimes'
# Finished separating Patrol Zone 649's crimes'
# Finished separating Patrol Zone 650's crimes'
# Finished separating Patrol Zone 651's crimes'
# Finished separating Patrol Zone 652's crimes'
# Finished separating Patrol Zone 653's crimes'
# Finished separating Patrol Zone 654's crimes'
# Finished separating Patrol Zone 655's crimes'
# Finished separating Patrol Zone 656's crimes'
# Finished separating Patrol Zone 657's crimes'
# Finished separating Patrol Zone 658's crimes'
# Finished separating Patrol Zone 659's crimes'
# Finished separating Patrol Zone 660's crimes'
# Finished separating Patrol Zone 661's crimes'
# Finished separating Patrol Zone 662's crimes'
# Finished separating Patrol Zone 663's crimes'
# Finished separating Patrol Zone 664's crimes'
# Finished separating Patrol Zone 665's crimes'
# Finished separating Patrol Zone 666's crimes'
# Finished separating Patrol Zone 667's crimes'
# Finished separating Patrol Zone 668's crimes'
# Finished separating Patrol Zone 669's crimes'
# Finished separating Patrol Zone 670's crimes'
# Finished separating Patrol Zone 671's crimes'
# Finished separating Patrol Zone 672's crimes'
# Finished separating Patrol Zone 673's crimes'
# Finished separating Patrol Zone 674's crimes'
# Finished separating Patrol Zone 675's crimes'
# Finished separating Patrol Zone 676's crimes'
# Finished separating Patrol Zone 677's crimes'
# Finished separating Patrol Zone 678's crimes'
# Finished separating Patrol Zone 679's crimes'
# Finished separating Patrol Zone 680's crimes'
# Finished separating Patrol Zone 681's crimes'
# Finished separating Patrol Zone 682's crimes'
# Finished separating Patrol Zone 683's crimes'
# Finished separating Patrol Zone 684's crimes'
# Finished separating Patrol Zone 685's crimes'
# Finished separating Patrol Zone 686's crimes'
# Finished separating Patrol Zone 687's crimes'
# Finished separating Patrol Zone 688's crimes'
# Finished separating Patrol Zone 689's crimes'
# Finished separating Patrol Zone 690's crimes'
# Finished separating Patrol Zone 691's crimes'
# Finished separating Patrol Zone 692's crimes'
# Finished separating Patrol Zone 693's crimes'
# Finished separating Patrol Zone 694's crimes'
# Finished separating Patrol Zone 695's crimes'
# Finished separating Patrol Zone 696's crimes'
# Finished separating Patrol Zone 697's crimes'
# 2306760

# %%
#Creating Dataframe of crime_patrol_pair
crime_patrol_pair_df = pd.DataFrame({'crime_index': crime_pair, 'patrol_index':patrol_pair})
crime_patrol_pair_df.head()
# Out:
#    crime_index  patrol_index
# 0           27             0
# 1           68             0
# 2          205             0
# 3          285             0
# 4          340             0

# %%
#Exporting final dataset of crimes linked to patrol zones
fileExport = path.join("..","Clean","final_version","final_crime_patrol_pair.csv")
crime_patrol_pair_df.to_csv(fileExport, sep=';', index=False)

#Exporting cinal dataset of Zonas de Patrullaje
fileExport = path.join("..","Clean","final_version","final_zonas_patrullaje_df.csv")
patrullaje_df.to_csv(fileExport, sep=';', index=False)

# %%
#Checking the exported file
exportFile_df = pd.read_csv(path.join("..","Clean","final_version","final_database.csv"), sep=';')

exportFile_df.head()
# Out:
#     Año      Mes          Alcaldía                    Categoría de delito  \
# 0  2018  Octubre    ALVARO OBREGON                 DELITO DE BAJO IMPACTO
# 1  2018  Octubre      AZCAPOTZALCO   ROBO DE VEHÍCULO CON Y SIN VIOLENCIA
# 2  2018  Octubre  GUSTAVO A MADERO                 DELITO DE BAJO IMPACTO
# 3  2018  Octubre  GUSTAVO A MADERO                 DELITO DE BAJO IMPACTO
# 4  2018  Octubre    MIGUEL HIDALGO  ROBO A REPARTIDOR CON Y SIN VIOLENCIA
#
#                                               Delito Unidad de investigación  \
# 0                                 ABUSO DE CONFIANZA                  UI-3CD
# 1  ROBO DE VEHICULO DE SERVICIO PÚBLICO CON VIOLE...                  UI-3SD
# 2                                    ROBO DE OBJETOS                  UI-3CD
# 3                                 ABUSO DE CONFIANZA                  UI-3SD
# 4                    ROBO A REPARTIDOR SIN VIOLENCIA                  UI-1SD
#
#           Fecha inicio                 Colonia                       Geopoint
# 0  2018-10-17 13:00:24  LAS AGUILAS 3ER PARQUE     19.35177196, -99.220583382
# 1  2018-10-17 13:03:39              EL ROSARIO  19.5085668561, -99.2083000919
# 2  2018-10-17 13:05:09       GUADALUPE TEPEYAC  19.4663394581, -99.1243321831
# 3  2018-10-17 13:09:04         EMILIANO ZAPATA  19.4628200485, -99.1163214933
# 4  2018-10-17 13:09:22              PERIODISTA  19.4503050199, -99.2199589505
